# %% [markdown]
# ### Import Efficient 3DCNN MobileNetV2

# %%
import sys
sys.path.append('../Face Liveness/Models/Efficient-3DCNNs-master/models')

# %%
from mobilenetv2 import MobileNetV2, get_model, get_fine_tuning_parameters
from copy import deepcopy

# %%
# Create an instance of the MobileNetV2 model
base_model = MobileNetV2(num_classes=600, sample_size=112, width_mult=0.45)

# %%
base_model.eval()
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv3d(3, 14, kernel_size=(3, 3, 3), stride=(1, 2, 2), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(14, 14, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=14, bias=False)
#         (1): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(14, 7, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (4): BatchNorm3d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(7, 42, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(42, 42, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=42, bias=False)
#         (4): BatchNorm3d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(42, 10, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(10, 60, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(60, 60, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=60, bias=False)
#         (4): BatchNorm3d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(60, 10, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(10, 60, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(60, 60, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=60, bias=False)
#         (4): BatchNorm3d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(60, 14, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(14, 84, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(84, 84, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=84, bias=False)
#         (4): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(84, 14, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(14, 84, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(84, 84, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=84, bias=False)
#         (4): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(84, 14, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(14, 84, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(84, 84, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=84, bias=False)
#         (4): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(84, 28, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(28, 168, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(168, 168, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=168, bias=False)
#         (4): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(168, 28, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(28, 168, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(168, 168, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=168, bias=False)
#         (4): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(168, 28, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(28, 168, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(168, 168, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=168, bias=False)
#         (4): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(168, 28, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(28, 168, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(168, 168, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=168, bias=False)
#         (4): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(168, 43, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(43, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(43, 258, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(258, 258, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=258, bias=False)
#         (4): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(258, 43, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(43, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(43, 258, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(258, 258, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=258, bias=False)
#         (4): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(258, 43, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(43, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(43, 258, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(258, 258, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=258, bias=False)
#         (4): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(258, 72, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(72, 432, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(432, 432, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=432, bias=False)
#         (4): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(432, 72, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(72, 432, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(432, 432, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=432, bias=False)
#         (4): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(432, 72, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(72, 432, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(432, 432, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=432, bias=False)
#         (4): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(432, 144, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Sequential(
#       (0): Conv3d(144, 1280, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=600, bias=True)
#   )
# )

# %% [markdown]
# ### Load the pre-train / checkpoint

# %%
import torch

checkpoint_path = './kinetics_mobilenetv2_0.45x_RGB_16_best.pth'

# Load the checkpoint
checkpoint = torch.load(checkpoint_path)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_33948\1772991293.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)

# %%
# Remove the 'module.' prefix from the state_dict keys
new_state_dict = {}
for k, v in checkpoint['state_dict'].items():
    new_key = k.replace('module.', '')  # Remove 'module.' from key names
    new_state_dict[new_key] = v

# Load the new state_dict into your model
base_model.load_state_dict(new_state_dict, strict=False)
# Out:
# <All keys matched successfully>

# %%
# Print the original classifier structure
print("Original classifier:", base_model.classifier)
# Out:
# Original classifier: Sequential(
#   (0): Dropout(p=0.2, inplace=False)
#   (1): Linear(in_features=1280, out_features=600, bias=True)
# )

# %%
# Access the last layer in the classifier to get in_features
if isinstance(base_model.classifier, torch.nn.Sequential):
    # Assuming the last layer is a Linear layer
    last_layer = base_model.classifier[-1]  # Access the last layer in the Sequential
    in_features = last_layer.in_features  # Get the number of input features
else:
    in_features = base_model.classifier.in_features  # If it's a Linear layer directly

print("Input features for the classifier:", in_features)
# Out:
# Input features for the classifier: 1280

# %% [markdown]
# ### Folders

# %%
train_folder = '../../Dataset/CASIA-FASD/train_release'
test_folder = '../../Dataset/CASIA-FASD/test_release'

new_train_folder = '../../Dataset/CASIA-FASD/train'
validation_folder = '../../Dataset/CASIA-FASD/validation'

# %%
import os
import shutil
import random
from video_dataset import VideoDataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
os.makedirs(new_train_folder, exist_ok=True)
os.makedirs(validation_folder, exist_ok=True)

# %%
identities = os.listdir(train_folder)

# split original train data --> train(80%)/validation(20%), original train data identities=20
num_val_identities = 4 #original train data * 0.2 = 4
val_identities = random.sample(identities, num_val_identities)

# %%
# Copy to new folders
def make_new_folder():
    for identity in identities:
        identity_path = os.path.join(train_folder, identity)

        if identity in val_identities:
            dest_folder = os.path.join(validation_folder, identity)
        else:
            dest_folder = os.path.join(new_train_folder, identity)

        os.makedirs(dest_folder, exist_ok=True)

        for video_file in os.listdir(identity_path):
            src_file = os.path.join(identity_path, video_file)
            shutil.copy(src_file, dest_folder)

# %%
# make_new_folder()

# %%
base_train_dataset = VideoDataset(train_folder)
base_train_loader = DataLoader(base_train_dataset)

# %%
# train_dataset = VideoDataset(new_train_folder)
# train_loader = DataLoader(train_dataset, batch_size=4, shuffle=False)

# %%
# validation_dataset = VideoDataset(validation_folder)
# validation_loader = DataLoader(validation_dataset, batch_size=4, shuffle=False)

# %%
test_dataset = VideoDataset(test_folder)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# %% [markdown]
# ##### Show sample of the first video

# %%
for frames, labels, identity in base_train_loader:  # Unpack frames and labels
    for i in range(frames.size(1)):  # frames.size(1) gives the number of frames in the first video
        # Move tensor to CPU and convert to numpy
        frame = frames[0][i].permute(1, 2, 0).cpu().numpy()  
        
        plt.imshow(frame)  # Show the i-th frame of the first video
        plt.axis('off')  # Hide axis
        plt.title(f'Frame {i + 1} of First Video')
        plt.show()
    
    break  # Exit after the first batch

# %% [markdown]
# #### Check data shape

# %%
# Check the length of the train dataset
print("Number of videos in train dataset:", len(base_train_dataset))
print("Number of videos in test dataset:", len(test_dataset))

# Check the return value of the first item in the dataset
sample_frames, sample_label, sample_identity = base_train_dataset[0]  # Get the first video
print("Return value for the first video (frames, label):", (sample_frames, sample_label))

# Check the shape of the frames
if isinstance(sample_frames, torch.Tensor):
    print("Shape of frames for the first video:", sample_frames.shape)
else:
    print("The first video frames are not a tensor, inspect further.")
# Out:
# Number of videos in train dataset: 240
# Number of videos in test dataset: 360
# Return value for the first video (frames, label): (tensor([[[[145, 147, 147,  ..., 160, 160, 158],
#           [145, 147, 147,  ..., 157, 157, 154],
#           [147, 147, 147,  ..., 157, 157, 155],
#           ...,
#           [ 34,  37,  39,  ..., 102, 100,  94],
#           [ 31,  34,  30,  ...,  92,  95, 104],
#           [ 29,  52,  28,  ..., 102, 101, 101]],
#
#          [[140, 142, 142,  ..., 145, 147, 141],
#           [140, 142, 142,  ..., 142, 144, 137],
#           [142, 142, 142,  ..., 142, 144, 138],
#           ...,
#           [ 20,  28,  35,  ...,  89,  91,  87],
#           [ 17,  25,  26,  ...,  89,  90,  93],
#           [ 15,  43,  24,  ...,  87,  89,  89]],
#
#          [[125, 127, 127,  ..., 141, 138, 142],
#           [125, 127, 127,  ..., 138, 135, 138],
#           [127, 127, 127,  ..., 137, 135, 139],
#           ...,
#           [ 18,  25,  31,  ...,  85,  83,  85],
#           [ 14,  22,  22,  ...,  84,  82,  90],
#           [ 13,  40,  20,  ...,  84,  82,  86]]],
#
#
#         [[[145, 148, 148,  ..., 156, 156, 154],
#           [145, 148, 148,  ..., 155, 155, 151],
#           [148, 148, 148,  ..., 154, 154, 153],
#           ...,
#           [ 36,  40,  39,  ...,  98, 100, 100],
#           [ 32,  33,  29,  ...,  99,  99,  99],
#           [ 30,  53,  29,  ...,  99,  99,  97]],
#
#          [[139, 142, 142,  ..., 143, 145, 141],
#           [139, 142, 142,  ..., 142, 144, 138],
#           [142, 142, 142,  ..., 141, 143, 140],
#           ...,
#           [ 22,  31,  35,  ...,  91,  90,  85],
#           [ 18,  24,  24,  ...,  90,  89,  89],
#           [ 16,  44,  24,  ...,  90,  89,  87]],
#
#          [[127, 130, 130,  ..., 139, 136, 137],
#           [127, 130, 130,  ..., 138, 135, 134],
#           [130, 130, 130,  ..., 137, 134, 136],
#           ...,
#           [ 20,  28,  31,  ...,  83,  85,  86],
#           [ 16,  21,  20,  ...,  82,  84,  89],
#           [ 14,  41,  20,  ...,  82,  84,  87]]],
#
#
#         [[[146, 147, 148,  ..., 160, 160, 159],
#           [146, 147, 148,  ..., 159, 159, 156],
#           [147, 148, 148,  ..., 154, 154, 154],
#           ...,
#           [ 35,  37,  40,  ...,  96,  98,  99],
#           [ 34,  31,  30,  ...,  96,  96,  98],
#           [ 27,  49,  27,  ...,  96,  96,  98]],
#
#          [[140, 141, 142,  ..., 146, 146, 144],
#           [140, 141, 142,  ..., 145, 145, 142],
#           [141, 142, 142,  ..., 140, 140, 139],
#           ...,
#           [ 21,  28,  35,  ...,  90,  92,  86],
#           [ 20,  22,  25,  ...,  88,  90,  90],
#           [ 16,  42,  24,  ...,  88,  90,  90]],
#
#          [[128, 129, 130,  ..., 139, 139, 140],
#           [128, 129, 130,  ..., 138, 138, 138],
#           [129, 130, 130,  ..., 133, 133, 135],
#           ...,
#           [ 19,  25,  33,  ...,  84,  82,  86],
#           [ 18,  19,  21,  ...,  82,  80,  90],
#           [ 13,  39,  20,  ...,  82,  80,  90]]],
#
#
#         ...,
#
#
#         [[[144, 144, 144,  ..., 157, 157, 155],
#           [144, 144, 144,  ..., 157, 157, 155],
#           [144, 144, 144,  ..., 155, 154, 151],
#           ...,
#           [ 29,  34,  36,  ..., 102, 102, 103],
#           [ 25,  29,  28,  ..., 102, 102, 104],
#           [ 18,  46,  32,  ..., 102, 102, 100]],
#
#          [[140, 140, 140,  ..., 143, 143, 141],
#           [140, 140, 140,  ..., 143, 143, 141],
#           [140, 140, 140,  ..., 141, 140, 137],
#           ...,
#           [ 22,  27,  31,  ...,  89,  88,  89],
#           [ 18,  22,  24,  ...,  89,  88,  90],
#           [ 11,  39,  27,  ...,  89,  88,  89]],
#
#          [[130, 130, 130,  ..., 141, 141, 139],
#           [130, 130, 130,  ..., 141, 141, 139],
#           [130, 130, 130,  ..., 139, 138, 135],
#           ...,
#           [ 19,  23,  30,  ...,  85,  86,  87],
#           [ 15,  19,  20,  ...,  85,  86,  88],
#           [  8,  36,  23,  ...,  85,  86,  86]]],
#
#
#         [[[144, 144, 144,  ..., 157, 155, 156],
#           [144, 144, 144,  ..., 155, 155, 155],
#           [144, 145, 146,  ..., 153, 151, 152],
#           ...,
#           [ 30,  35,  39,  ..., 100, 101, 100],
#           [ 28,  32,  32,  ...,  98,  98,  99],
#           [ 22,  48,  28,  ...,  98,  99,  96]],
#
#          [[140, 140, 140,  ..., 143, 141, 142],
#           [140, 140, 140,  ..., 141, 141, 141],
#           [140, 141, 142,  ..., 139, 137, 138],
#           ...,
#           [ 23,  28,  34,  ...,  91,  91,  90],
#           [ 21,  25,  28,  ...,  89,  88,  89],
#           [ 15,  41,  24,  ...,  89,  89,  87]],
#
#          [[130, 130, 130,  ..., 141, 139, 140],
#           [130, 130, 130,  ..., 139, 139, 139],
#           [130, 131, 132,  ..., 137, 135, 136],
#           ...,
#           [ 20,  25,  33,  ...,  83,  86,  85],
#           [ 18,  22,  24,  ...,  81,  83,  84],
#           [ 12,  38,  20,  ...,  81,  84,  82]]],
#
#
#         [[[146, 146, 146,  ..., 159, 160, 159],
#           [146, 146, 146,  ..., 157, 157, 156],
#           [146, 148, 148,  ..., 154, 154, 158],
#           ...,
#           [ 35,  40,  41,  ..., 101, 102, 101],
#           [ 32,  34,  34,  ...,  99,  99, 101],
#           [ 26,  55,  32,  ...,  99, 100,  97]],
#
#          [[140, 140, 140,  ..., 144, 145, 144],
#           [140, 140, 140,  ..., 142, 142, 141],
#           [140, 142, 142,  ..., 139, 139, 143],
#           ...,
#           [ 24,  29,  30,  ...,  88,  89,  87],
#           [ 21,  23,  23,  ...,  86,  86,  88],
#           [ 15,  44,  21,  ...,  86,  87,  86]],
#
#          [[130, 130, 130,  ..., 140, 141, 140],
#           [130, 130, 130,  ..., 138, 138, 137],
#           [130, 132, 132,  ..., 135, 135, 138],
#           ...,
#           [ 21,  26,  27,  ...,  84,  85,  85],
#           [ 18,  20,  20,  ...,  82,  82,  84],
#           [ 12,  41,  18,  ...,  82,  83,  83]]]], dtype=torch.uint8), 1)
# Shape of frames for the first video: torch.Size([16, 3, 112, 112])

# %% [markdown]
# ### Insert Data to Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(device)
# Out:
# cuda

# %%
import torch.nn as nn
import torch.optim as optim

# %%
num_classes = 2
base_model.classifier[1] = nn.Linear(base_model.last_channel, num_classes)

# %%
base_model = base_model.to(device)

# %%
base_model.eval()
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv3d(3, 14, kernel_size=(3, 3, 3), stride=(1, 2, 2), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(14, 14, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=14, bias=False)
#         (1): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(14, 7, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (4): BatchNorm3d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(7, 42, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(42, 42, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=42, bias=False)
#         (4): BatchNorm3d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(42, 10, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(10, 60, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(60, 60, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=60, bias=False)
#         (4): BatchNorm3d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(60, 10, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(10, 60, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(60, 60, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=60, bias=False)
#         (4): BatchNorm3d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(60, 14, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(14, 84, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(84, 84, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=84, bias=False)
#         (4): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(84, 14, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(14, 84, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(84, 84, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=84, bias=False)
#         (4): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(84, 14, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(14, 84, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(84, 84, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=84, bias=False)
#         (4): BatchNorm3d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(84, 28, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(28, 168, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(168, 168, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=168, bias=False)
#         (4): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(168, 28, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(28, 168, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(168, 168, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=168, bias=False)
#         (4): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(168, 28, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(28, 168, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(168, 168, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=168, bias=False)
#         (4): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(168, 28, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(28, 168, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(168, 168, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=168, bias=False)
#         (4): BatchNorm3d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(168, 43, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(43, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(43, 258, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(258, 258, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=258, bias=False)
#         (4): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(258, 43, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(43, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(43, 258, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(258, 258, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=258, bias=False)
#         (4): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(258, 43, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(43, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(43, 258, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(258, 258, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=258, bias=False)
#         (4): BatchNorm3d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(258, 72, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(72, 432, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(432, 432, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=432, bias=False)
#         (4): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(432, 72, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(72, 432, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(432, 432, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=432, bias=False)
#         (4): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(432, 72, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv3d(72, 432, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv3d(432, 432, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=432, bias=False)
#         (4): BatchNorm3d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv3d(432, 144, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (7): BatchNorm3d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Sequential(
#       (0): Conv3d(144, 1280, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=2, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(base_model.parameters(), lr=0.0001)

# %%
num_epochs = 10
patience = 3
train_losses = []

# %%
def train(model, train_loader, criterion, optimizer, num_epochs, device):
    model.train()  # Set model to training mode
    train_losses = []

    for epoch in range(num_epochs):
        running_loss = 0.0
        model.train()  # Ensure model is in training mode

        # Training phase
        for i, (inputs, labels, _) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            inputs = inputs.permute(0, 2, 1, 3, 4)

            # Convert inputs to float if they are not already
            if inputs.dtype != torch.float32:
                inputs = inputs.float()  # Convert to FloatTensor

            optimizer.zero_grad()  # Zero the parameter gradients

            # Forward + backward + optimize
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Calculate average training loss
        avg_train_loss = running_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {avg_train_loss:.4f}")

    print("Base training complete.")

    return model, train_losses

# %%
model, train_losses = train(base_model, base_train_loader, criterion, optimizer, num_epochs, device)
# Out:
# Epoch 1/10, Train Loss: 0.5832
# Epoch 2/10, Train Loss: 0.5561
# Epoch 3/10, Train Loss: 0.4879
# Epoch 4/10, Train Loss: 0.3208
# Epoch 5/10, Train Loss: 0.1822
# Epoch 6/10, Train Loss: 0.1053
# Epoch 7/10, Train Loss: 0.0705
# Epoch 8/10, Train Loss: 0.0516
# Epoch 9/10, Train Loss: 0.0378
# Epoch 10/10, Train Loss: 0.0296
# Base training complete.

# %%
print(train_losses)
# Out:
# [0.5832416392241915, 0.5560812269027035, 0.48785876147449014, 0.3208248382123808, 0.18223989776646096, 0.10531788216903806, 0.07052575293152283, 0.05155464531853795, 0.037848317467917995, 0.029580504940046617]

# %%
def plot_losses(name, losses):
    plt.figure(figsize=(10, 5))
    plt.plot(losses, label=f'{name} losses', color='blue', marker='o')
    plt.title(f'{name} Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.xticks(range(len(losses)))  # Set x-ticks to be the epoch numbers
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
plot_losses('Train', train_losses)

# %%
from sklearn.metrics import classification_report

# %%
def test(model, test_loader, criterion, device):
    model.eval()  # Set the model to evaluation mode
    test_losses = []
    all_predictions = []
    all_labels = []

    with torch.no_grad():  # No gradient calculation is needed during testing
        for inputs, labels, _ in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            inputs = inputs.permute(0, 2, 1, 3, 4)  # Adjust input dimensions if necessary

            if inputs.dtype != torch.float32:
                inputs = inputs.float()  # Convert to FloatTensor

            outputs = model(inputs)  # Forward pass
            loss = criterion(outputs, labels)  # Compute loss
            test_losses.append(loss.item())  # Store the loss for later

            # Get the predicted class
            _, predicted = torch.max(outputs.data, 1)  # Get the index of the max log-probability

            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    avg_test_loss = sum(test_losses) / len(test_losses) if test_losses else 0

    print(classification_report(all_labels, all_predictions, target_names=['Genuine', 'Spoof']))
    return avg_test_loss

# %%
test_loss = test(model, test_loader, criterion, device)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 test_loss = test(model, test_loader, criterion, device)
#
# Cell In[39], line 8, in test(model, test_loader, criterion, device)
#       5 all_labels = []
#       7 with torch.no_grad():  # No gradient calculation is needed during testing
# ----> 8     for inputs, labels in test_loader:
#       9         inputs, labels = inputs.to(device), labels.to(device)
#      10         inputs = inputs.permute(0, 2, 1, 3, 4)  # Adjust input dimensions if necessary
#
# ValueError: too many values to unpack (expected 2)
